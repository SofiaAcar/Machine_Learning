# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# In this project, you must apply EDA processes for the development of predictive models. Handling outliers, domain knowledge and feature engineering will be challenges.
#
# Also, this project aims to improve your ability to implement algorithms for Multi-Class Classification. Thus, you will have the opportunity to implement many algorithms commonly used for Multi-Class Classification problems.
#
# Before diving into the project, please take a look at the determines and tasks.

# %% [markdown]
# # Determines

# %% [markdown]
# The 2012 US Army Anthropometric Survey (ANSUR II) was executed by the Natick Soldier Research, Development and Engineering Center (NSRDEC) from October 2010 to April 2012 and is comprised of personnel representing the total US Army force to include the US Army Active Duty, Reserves, and National Guard. In addition to the anthropometric and demographic data described below, the ANSUR II database also consists of 3D whole body, foot, and head scans of Soldier participants. These 3D data are not publicly available out of respect for the privacy of ANSUR II participants. The data from this survey are used for a wide range of equipment design, sizing, and tariffing applications within the military and has many potential commercial, industrial, and academic applications.
#
# The ANSUR II working databases contain 93 anthropometric measurements which were directly measured, and 15 demographic/administrative variables explained below. The ANSUR II Male working database contains a total sample of 4,082 subjects. The ANSUR II Female working database contains a total sample of 1,986 subjects.
#
#
# DATA DICT:
# https://data.world/datamil/ansur-ii-data-dictionary/workspace/file?filename=ANSUR+II+Databases+Overview.pdf
#
# ---
#
# To achieve high prediction success, you must understand the data well and develop different approaches that can affect the dependent variable.
#
# Firstly, try to understand the dataset column by column using pandas module. Do research within the scope of domain (body scales, and race characteristics) knowledge on the internet to get to know the data set in the fastest way.
#
# You will implement ***Logistic Regression, Support Vector Machine, XGBoost, Random Forest*** algorithms. Also, evaluate the success of your models with appropriate performance metrics.
#
# At the end of the project, choose the most successful model and try to enhance the scores with ***SMOTE*** make it ready to deploy. Furthermore, use ***SHAP*** to explain how the best model you choose works.

# %% [markdown]
# # Tasks

# %% [markdown]
# #### 1. Exploratory Data Analysis (EDA)
# - Import Libraries, Load Dataset, Exploring Data
#
#     *i. Import Libraries*
#
#     *ii. Ingest Data *
#
#     *iii. Explore Data*
#
#     *iv. Outlier Detection*
#
#     *v.  Drop unnecessary features*
#
# #### 2. Data Preprocessing
# - Scale (if needed)
# - Separete the data frame for evaluation purposes
#
# #### 3. Multi-class Classification
# - Import libraries
# - Implement SVM Classifer
# - Implement Decision Tree Classifier
# - Implement Random Forest Classifer
# - Implement XGBoost Classifer
# - Compare The Models

# %% [markdown]
# # EDA
# - Drop unnecessary colums
# - Drop DODRace class if value count below 500 (we assume that our data model can't learn if it is below 500)

# %% [markdown]
# ## Import Libraries
# Besides Numpy and Pandas, you need to import the necessary modules for data visualization, data preprocessing, Model building and tuning.
#
# *Note: Check out the course materials.*

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
#%matplotlib notebook
plt.rcParams["figure.figsize"] = (10,6)
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# ## Ingest Data from links below and make a dataframe
# - Soldiers Male : https://query.data.world/s/h3pbhckz5ck4rc7qmt2wlknlnn7esr
# - Soldiers Female : https://query.data.world/s/sq27zz4hawg32yfxksqwijxmpwmynq

# %%
female = pd.read_csv("ANSUR II FEMALE Public.csv", encoding='latin-1')
male = pd.read_csv("ANSUR II MALE Public.csv", encoding='latin-1')

# %%
female.head()
# Out:
#    SubjectId  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# ...

# %%
female.shape
# Out:
# (1986, 108)

# %%
female = female.rename({'SubjectId': 'subjectid'}, axis=1)

# %%
female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Columns: 108 entries, subjectid to WritingPreference
# dtypes: int64(99), object(9)
# memory usage: 1.6+ MB

# %%
female.isna().sum().any()
# Out:
# True

# %%
male.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10027                             266            1467
# 1      10032                             233            1395
# 2      10033                             287            1430
# 3      10092                             234            1347
# 4      10093                             250            1585
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    337                 222          1347
# 1                    326                 220          1293
# 2                    341                 230          1327
# 3                    310                 230          1239
# 4                    372                 247          1478
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      253               202                401
# 1                      245               193                394
# ...

# %%
male.shape
# Out:
# (4082, 108)

# %%
male.isna().sum().any()
# Out:
# True

# %% [markdown]
# ## Explore Data

# %%
df = pd.concat([female, male], ignore_index = True)

# %%
df.shape
# Out:
# (6068, 108)

# %%
df.head()
# Out:
#    subjectid  abdominalextensiondepthsitting  acromialheight  \
# 0      10037                             231            1282
# 1      10038                             194            1379
# 2      10042                             183            1369
# 3      10043                             261            1356
# 4      10051                             309            1303
#
#    acromionradialelength  anklecircumference  axillaheight  \
# 0                    301                 204          1180
# 1                    320                 207          1292
# 2                    329                 233          1271
# 3                    306                 214          1250
# 4                    308                 214          1210
#
#    balloffootcircumference  balloffootlength  biacromialbreadth  \
# 0                      222               177                373
# 1                      225               178                372
# ...

# %%
df.drop(['Date', 'Component', 'Installation', 'Branch', 'PrimaryMOS', 'SubjectNumericRace', 'Weightlbs', "Ethnicity", 'Heightin', 'subjectid'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# 2                 233          1271                      237
# 3                 214          1250                      240
# 4                 214          1210                      217
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               177                373                        315
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df[df.DODRace < 4]

# %%
df.DODRace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# Name: DODRace, dtype: int64

# %%
df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5769 entries, 0 to 6067
# Data columns (total 98 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   abdominalextensiondepthsitting  5769 non-null   int64
#  1   acromialheight                  5769 non-null   int64
#  2   acromionradialelength           5769 non-null   int64
#  3   anklecircumference              5769 non-null   int64
#  4   axillaheight                    5769 non-null   int64
#  5   balloffootcircumference         5769 non-null   int64
#  6   balloffootlength                5769 non-null   int64
#  7   biacromialbreadth               5769 non-null   int64
#  8   bicepscircumferenceflexed       5769 non-null   int64
#  9   bicristalbreadth                5769 non-null   int64
#  10  bideltoidbreadth                5769 non-null   int64
#  11  bimalleolarbreadth              5769 non-null   int64
# ...

# %%
def show_nans(df, limit):
    missing = df.isnull().sum()*100/df.shape[0]
    return missing.loc[lambda x : x >= limit]

show_nans(df,20)
# Out:
# Series([], dtype: float64)

# %%
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 150

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# abdominalextensiondepthsitting   0.000
# acromialheight                   0.000
# acromionradialelength            0.000
# anklecircumference               0.000
# axillaheight                     0.000
# balloffootcircumference          0.000
# balloffootlength                 0.000
# biacromialbreadth                0.000
# bicepscircumferenceflexed        0.000
# bicristalbreadth                 0.000
# bideltoidbreadth                 0.000
# bimalleolarbreadth               0.000
# bitragionchinarc                 0.000
# bitragionsubmandibulararc        0.000
# bizygomaticbreadth               0.000
# buttockcircumference             0.000
# buttockdepth                     0.000
# buttockheight                    0.000
# buttockkneelength                0.000
# buttockpopliteallength           0.000
# calfcircumference                0.000
# cervicaleheight                  0.000
# chestbreadth                     0.000
# chestcircumference               0.000
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.DODRace.value_counts()
# Out:
# 1    3792
# 2    1298
# 3     679
# Name: DODRace, dtype: int64

# %%
df["DODRace"].replace({1:"White", 2: "Black", 3: "Hispanic"}, inplace=True)

# %%
df.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# 2                 233          1271                      237
# 3                 214          1250                      240
# 4                 214          1210                      217
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               177                373                        315
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5769, 98)

# %%
df.SubjectsBirthLocation.value_counts()
# Out:
# California                417
# New York                  411
# Texas                     386
# Indiana                   264
# Florida                   210
# Illinois                  210
# Oklahoma                  205
# Michigan                  194
# Minnesota                 194
# Mississippi               193
# Georgia                   168
# Alabama                   164
# South Carolina            161
# North Carolina            145
# Ohio                      139
# Louisiana                 136
# Pennsylvania              130
# Virginia                  113
# Massachusetts             109
# Wisconsin                  99
# Germany                    90
# New Jersey                 88
# Puerto Rico                88
# Missouri                   83
# Maryland                   78
# Colorado                   78
# Arizona                    75
# Tennessee                  74
# Kentucky                   67
# Kansas                     62
# Washington                 61
# ...

# %% [markdown]
# Guclu correlation iliskisi olan feature' lar var fakat kullanacagimiz modellerde bu durum sorun teskil etmeyecek :

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), cmap='coolwarm');

# %%
sns.countplot(df.DODRace);

# %% [markdown]
# __Hispanic class' ina ait veriler oldukca az.Datada unbalance bir durum var.__

# %% [markdown]
# # DATA Preprocessing
# - In this step we divide our data to X(Features) and y(Target) then ,
# - To train and evaluation purposes we create train and test sets,
# - Lastly, scale our data if features not in same scale. Why?

# %%
X = pd. get_dummies(df.drop('DODRace', axis = 1), drop_first = True)
y = df.DODRace

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 101)

# %% [markdown]
# # Modelling
# - Fit the model with train dataset
# - Get predict from vanilla model on both train and test sets to examine if there is over/underfitting
# - Apply GridseachCV for both hyperparemeter tuning and sanity test of our model.
# - Use hyperparameters that you find from gridsearch and make final prediction and evaluate the result according to chosen metric.

# %% [markdown]
# ## 1. Logistic model

# %% [markdown]
# ### Scaling

# %%
from sklearn.pipeline import Pipeline

# %%
operations = [('scaler', MinMaxScaler()), ('log', LogisticRegression())]

# %%
pipe_model_vanilla = Pipeline(steps=operations)

# %% [markdown]
# ### Vanilla Logistic Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
pipe_model_vanilla.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('log', LogisticRegression())])

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
def eval_metric(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    y_pred = model.predict(X_test)
    
    print("Test_Set")
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    print()
    print("Train_Set")
    print(confusion_matrix(y_train, y_train_pred))
    print(classification_report(y_train, y_train_pred))

# %%
eval_metric(pipe_model_vanilla, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[296   3  35]
#  [  8  87  66]
#  [  8  19 921]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.89      0.92       334
#     Hispanic       0.80      0.54      0.64       161
#        White       0.90      0.97      0.94       948
#
#     accuracy                           0.90      1443
#    macro avg       0.88      0.80      0.83      1443
# weighted avg       0.90      0.90      0.90      1443
#
#
# Train_Set
# [[ 886   14   64]
#  [  27  284  207]
#  [  24   49 2771]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.92      0.93       964
#     Hispanic       0.82      0.55      0.66       518
#        White       0.91      0.97      0.94      2844
#
#     accuracy                           0.91      4326
#    macro avg       0.89      0.81      0.84      4326
# weighted avg       0.91      0.91      0.91      4326

# %% [markdown]
# Vanilla model ile skorlar cok kotu. Parametreler ile durumu duzeltmeye calisalim :

# %%
operations_weighted = [('scaler', MinMaxScaler()), ('log', LogisticRegression(class_weight='balanced', max_iter=10000, random_state = 101))]

# %%
pipe_model = Pipeline(steps=operations_weighted)

# %%
pipe_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     random_state=101))])

# %%
eval_metric(pipe_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[303  19  12]
#  [  8 135  18]
#  [ 19 123 806]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.91      0.91       334
#     Hispanic       0.49      0.84      0.62       161
#        White       0.96      0.85      0.90       948
#
#     accuracy                           0.86      1443
#    macro avg       0.79      0.87      0.81      1443
# weighted avg       0.90      0.86      0.87      1443
#
#
# Train_Set
# [[ 904   37   23]
#  [  17  436   65]
#  [  55  337 2452]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93       964
#     Hispanic       0.54      0.84      0.66       518
#        White       0.97      0.86      0.91      2844
#
#     accuracy                           0.88      4326
#    macro avg       0.81      0.88      0.83      4326
# weighted avg       0.91      0.88      0.89      4326

# %% [markdown]
# ### Cross Validate

# %%
from sklearn.model_selection import cross_validate

# %%
from sklearn.metrics import make_scorer

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score

# %%
operations_weighted = [('scaler', MinMaxScaler()), ('log', LogisticRegression(class_weight='balanced', max_iter=10000, random_state = 101))]

# %%
pipe_model = Pipeline(steps=operations_weighted)

# %%
scoring = {"f1_Hispanic" : make_scorer(f1_score, average = None, labels =["Hispanic"]),
           "precision_Hispanic" : make_scorer(precision_score, average = None, labels =["Hispanic"]),
           "recall_Hispanic" : make_scorer(recall_score, average = None, labels =["Hispanic"])}

# %% [markdown]
# Cross Validate isleminden sonra Hispanic class' ina ait skorlar yukaridaki tek seferlik skorlar ile dengeli :

# %%
scores = cross_validate(pipe_model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.609
# test_precision_Hispanic   0.506
# test_recall_Hispanic      0.768
# dtype: float64

# %% [markdown]
# ### Logistic Model GridsearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
recall_Hispanic = make_scorer(recall_score, average=None, labels=['Hispanic'])

# %%
param_grid = {
    "log__C": [0.1, 0.5, 1],
    'log__penalty': ["l1", "l2"],
    'log__solver': ['liblinear', 'lbfgs', 'saga'],
}

# %%
operations_weighted = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101))]

# %%
pipe_model = Pipeline(steps=operations_weighted)

# %%
log_model_grid = GridSearchCV(pipe_model, param_grid, verbose=3, scoring=recall_Hispanic, n_jobs=-1, cv=5)

# %%
log_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('log',
#                                         LogisticRegression(class_weight='balanced',
#                                                            max_iter=10000,
#                                                            random_state=101))]),
#              n_jobs=-1,
#              param_grid={'log__C': [0.1, 0.5, 1], 'log__penalty': ['l1', 'l2'],
#                          'log__solver': ['liblinear', 'lbfgs', 'saga']},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
log_model_grid.best_params_
# Out:
# {'log__C': 0.5, 'log__penalty': 'l1', 'log__solver': 'saga'}

# %%
log_model_grid.best_score_
# Out:
# 0.7662621359223302

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[302  18  14]
#  [  8 132  21]
#  [ 21 129 798]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.90      0.91       334
#     Hispanic       0.47      0.82      0.60       161
#        White       0.96      0.84      0.90       948
#
#     accuracy                           0.85      1443
#    macro avg       0.78      0.86      0.80      1443
# weighted avg       0.89      0.85      0.87      1443
#
#
# Train_Set
# [[ 899   40   25]
#  [  22  419   77]
#  [  65  344 2435]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.93      0.92       964
#     Hispanic       0.52      0.81      0.63       518
#        White       0.96      0.86      0.91      2844
#
#     accuracy                           0.87      4326
#    macro avg       0.80      0.87      0.82      4326
# weighted avg       0.90      0.87      0.88      4326

# %% [markdown]
# ### Precision-Recall Curve

# %%
from yellowbrick.classifier import PrecisionRecallCurve

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101))]

# %%
pipe_model = Pipeline(steps=operations)

# %%
viz = PrecisionRecallCurve(
    pipe_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],   # Tabloda isimler gorunsun diye bunu yazdik.
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ## 2. SVC

# %% [markdown]
# ### Vanilla SVC model

# %%
from sklearn.svm import SVC

# %%
operations_svc = [('scaler', MinMaxScaler()), ('svc', SVC(class_weight='balanced', random_state=101))]

# %%
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
pipe_svc_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('svc', SVC(class_weight='balanced', random_state=101))])

# %%
eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[293  20  21]
#  [ 10 127  24]
#  [ 16 142 790]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.88      0.90       334
#     Hispanic       0.44      0.79      0.56       161
#        White       0.95      0.83      0.89       948
#
#     accuracy                           0.84      1443
#    macro avg       0.77      0.83      0.78      1443
# weighted avg       0.88      0.84      0.85      1443
#
#
# Train_Set
# [[ 887   39   38]
#  [  17  429   72]
#  [  55  382 2407]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92       964
#     Hispanic       0.50      0.83      0.63       518
#        White       0.96      0.85      0.90      2844
#
#     accuracy                           0.86      4326
#    macro avg       0.80      0.86      0.82      4326
# weighted avg       0.90      0.86      0.87      4326

# %% [markdown]
# ### Cross Validate

# %%
operations_svc = [('scaler', MinMaxScaler()), ('svc', SVC(class_weight='balanced', random_state=101))]

# %%
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
scores = cross_validate(pipe_svc_model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1,11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.578
# test_precision_Hispanic   0.469
# test_recall_Hispanic      0.755
# dtype: float64

# %% [markdown]
# ###  SVC Model GridsearchCV

# %%
param_grid = {
    'svc__C': np.logspace(-1, 10, 10),
    'svc__gamma': ["scale", "auto", 1, 0.1, 0.01],               
}

# %%
operations_svc = [('scaler', MinMaxScaler()), ('svc', SVC(class_weight='balanced', random_state=101))]

# %%
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
svc_model_grid = GridSearchCV(pipe_svc_model, param_grid, verbose=3, scoring=recall_Hispanic, n_jobs=-1)

# %%
svc_model_grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# GridSearchCV(estimator=Pipeline(steps=[('scaler', MinMaxScaler()),
#                                        ('svc',
#                                         SVC(class_weight='balanced',
#                                             random_state=101))]),
#              n_jobs=-1,
#              param_grid={'svc__C': array([1.00000000e-01, 1.66810054e+00, 2.78255940e+01, 4.64158883e+02,
#        7.74263683e+03, 1.29154967e+05, 2.15443469e+06, 3.59381366e+07,
#        5.99484250e+08, 1.00000000e+10]),
#                          'svc__gamma': ['scale', 'auto', 1, 0.1, 0.01]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
svc_model_grid.best_params_
# Out:
# {'svc__C': 27.825594022071257, 'svc__gamma': 'auto'}

# %% [markdown]
# Datada overfitting durumu oldugu zaman GridSearch once C parametresini kucultur. Grid Search' un burada buldugu C degeri oldukca yuksek cikti. Train ve test set skorlari birbirine yakin ciktigi icin herhangi bir overfitting durumu yok. Bu degerle yola devam edebiliriz. Durumu teyit etmek icin GridSearch islemi sonrasi bir Cross Validate islemi daha yapacagiz.

# %%
svc_model_grid.best_score_
# Out:
# 0.7663554891710233

# %%
eval_metric(svc_model_grid, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[302  17  15]
#  [  8 129  24]
#  [ 18 138 792]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.90      0.91       334
#     Hispanic       0.45      0.80      0.58       161
#        White       0.95      0.84      0.89       948
#
#     accuracy                           0.85      1443
#    macro avg       0.78      0.85      0.79      1443
# weighted avg       0.89      0.85      0.86      1443
#
#
# Train_Set
# [[ 890   42   32]
#  [  18  422   78]
#  [  51  348 2445]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.93       964
#     Hispanic       0.52      0.81      0.63       518
#        White       0.96      0.86      0.91      2844
#
#     accuracy                           0.87      4326
#    macro avg       0.80      0.87      0.82      4326
# weighted avg       0.90      0.87      0.88      4326

# %% [markdown]
# ### Cross Validate for GridSearch

# %%
operations_svc = [('scaler', MinMaxScaler()), ('svc', SVC(class_weight = 'balanced', C = 27.825594022071257, gamma = 'auto',  random_state=101))]

# %%
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
scores = cross_validate(pipe_svc_model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1,11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.597
# test_precision_Hispanic   0.491
# test_recall_Hispanic      0.764
# dtype: float64

# %% [markdown]
# ### Precision Recall Curve

# %%
operations_svc = [('scaler', MinMaxScaler()), ('svc', SVC(class_weight='balanced', random_state=101))]

# %%
pipe_svc_model = Pipeline(steps=operations_svc)

# %%
viz = PrecisionRecallCurve(
    pipe_svc_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],   # Tabloda isimler gorunsun diye bunu yazdik.
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %% [markdown]
# ## 3. RF

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
X2 = df.drop('DODRace', axis=1)
y = df.DODRace

# %%
cat = X2.select_dtypes('object').columns
cat
# Out:
# Index(['Gender', 'SubjectsBirthLocation', 'WritingPreference'], dtype='object')

# %%
X2[cat]
# Out:
#       Gender SubjectsBirthLocation WritingPreference
# 0     Female               Germany        Right hand
# 1     Female            California        Right hand
# 2     Female                 Texas        Right hand
# 3     Female  District of Columbia        Right hand
# 4     Female                 Texas        Right hand
# ...      ...                   ...               ...
# 6063    Male              Colorado        Right hand
# 6064    Male              Oklahoma        Right hand
# 6065    Male              Oklahoma        Right hand
# 6066    Male              Oklahoma        Right hand
# 6067    Male              Oklahoma        Right hand
#
# [5769 rows x 3 columns]

# %%
encoder = OrdinalEncoder()

# %%
X2[cat] = encoder.fit_transform(X2[cat])

# %%
X2.head()
# Out:
#    abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# 0                             231            1282                    301
# 1                             194            1379                    320
# 2                             183            1369                    329
# 3                             261            1356                    306
# 4                             309            1303                    308
#
#    anklecircumference  axillaheight  balloffootcircumference  \
# 0                 204          1180                      222
# 1                 207          1292                      225
# 2                 233          1271                      237
# 3                 214          1250                      240
# 4                 214          1210                      217
#
#    balloffootlength  biacromialbreadth  bicepscircumferenceflexed  \
# 0               177                373                        315
# ...

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y, test_size = 0.25, random_state = 101)

# %% [markdown]
# ### Vanilla RF Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(class_weight='balanced', random_state=101)

# %%
rf_model.fit(X2_train, y2_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=101)

# %% [markdown]
# RF modelde vanilla degerler ile alinan Train skorlari cok iyi olmasina ragmen Test skorlari cok dusuk. Overfitting durumu var. Asagida GridSearch islemi ile skorlarimizi iyilestirmeye calisacagiz :

# %%
eval_metric(rf_model, X2_train, y2_train, X2_test, y2_test)
# Out:
# Test_Set
# [[222   0 112]
#  [ 12   3 146]
#  [  9   6 933]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.66      0.77       334
#     Hispanic       0.33      0.02      0.04       161
#        White       0.78      0.98      0.87       948
#
#     accuracy                           0.80      1443
#    macro avg       0.68      0.56      0.56      1443
# weighted avg       0.76      0.80      0.76      1443
#
#
# Train_Set
# [[ 964    0    0]
#  [   0  518    0]
#  [   0    0 2844]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00       964
#     Hispanic       1.00      1.00      1.00       518
#        White       1.00      1.00      1.00      2844
#
#     accuracy                           1.00      4326
#    macro avg       1.00      1.00      1.00      4326
# weighted avg       1.00      1.00      1.00      4326

# %% [markdown]
# ### Cross Validate

# %%
rf_model = RandomForestClassifier(class_weight='balanced', random_state=101)

# %% [markdown]
# Cross Validate islem sonucu ile tek seferlik skorlar birbirleri ile dengeli degil :

# %%
scores = cross_validate(rf_model, X2_train, y2_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1,11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.091
# test_precision_Hispanic   0.767
# test_recall_Hispanic      0.048
# dtype: float64

# %% [markdown]
# ### RF Model GridsearchCV

# %%
param_grid = {'n_estimators':[64, 128, 400,500],
             'max_depth':[10,12,14,16],
             'min_samples_split':[18,20,22],
             'max_features': ['auto', None, 15, 20]}

# %%
rf_model = RandomForestClassifier(class_weight='balanced', random_state=101)

# %%
rf_grid_model = GridSearchCV(rf_model,
                             param_grid,
                             verbose=3,
                             scoring=recall_Hispanic,
                             n_jobs=-1)

# %%
rf_grid_model.fit(X2_train, y2_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# GridSearchCV(estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=101),
#              n_jobs=-1,
#              param_grid={'max_depth': [10, 12, 14, 16],
#                          'max_features': ['auto', None, 15, 20],
#                          'min_samples_split': [18, 20, 22],
#                          'n_estimators': [64, 128, 400, 500]},
#              scoring=make_scorer(recall_score, average=None, labels=['Hispanic']),
#              verbose=3)

# %%
rf_grid_model.best_params_
# Out:
# {'max_depth': 10,
#  'max_features': 15,
#  'min_samples_split': 22,
#  'n_estimators': 64}

# %%
rf_grid_model.best_score_
# Out:
# 0.39178491411501126

# %%
eval_metric(rf_grid_model, X2_train, y2_train, X2_test, y2_test)
# Out:
# Test_Set
# [[265  10  59]
#  [ 23  54  84]
#  [ 48  96 804]]
#               precision    recall  f1-score   support
#
#        Black       0.79      0.79      0.79       334
#     Hispanic       0.34      0.34      0.34       161
#        White       0.85      0.85      0.85       948
#
#     accuracy                           0.78      1443
#    macro avg       0.66      0.66      0.66      1443
# weighted avg       0.78      0.78      0.78      1443
#
#
# Train_Set
# [[ 924    8   32]
#  [  13  468   37]
#  [  45   91 2708]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.96      0.95       964
#     Hispanic       0.83      0.90      0.86       518
#        White       0.98      0.95      0.96      2844
#
#     accuracy                           0.95      4326
#    macro avg       0.91      0.94      0.93      4326
# weighted avg       0.95      0.95      0.95      4326

# %% [markdown]
# ### Feature Importance

# %%
rf_grid_model = RandomForestClassifier(class_weight='balanced', max_depth=10, max_features=15, min_samples_split=22, n_estimators=64, random_state=101)
rf_grid_model.fit(X2_train, y2_train)
rf_grid_model.feature_importances_
feats = pd.DataFrame(index=X2.columns, data=rf_grid_model.feature_importances_, columns = ["Feature Importance"])
rf_feature_imp = feats.sort_values("Feature Importance", ascending = False)
rf_feature_imp
# Out:
#                                 Feature Importance
# sittingheight                                0.055
# eyeheightsitting                             0.051
# elbowrestheight                              0.043
# buttockpopliteallength                       0.042
# interpupillarybreadth                        0.038
# heelbreadth                                  0.034
# bicristalbreadth                             0.033
# buttockkneelength                            0.027
# radialestylionlength                         0.027
# bitragionchinarc                             0.024
# handlength                                   0.022
# wristheight                                  0.019
# headcircumference                            0.018
# earlength                                    0.018
# forearmhandlength                            0.017
# waistbreadth                                 0.016
# buttockheight                                0.015
# ...

# %%
plt.figure(figsize=(30,20))
sns.barplot(data=rf_feature_imp, x=rf_feature_imp.index, y='Feature Importance')

plt.xticks(rotation=90);

# %% [markdown]
# ### Precision Recall Curve

# %%
rf_grid_model = RandomForestClassifier(class_weight='balanced', max_depth=10, max_features=15, min_samples_split=22, n_estimators=64, random_state=101)

viz = PrecisionRecallCurve(
    rf_grid_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X2_train, y2_train)
viz.score(X2_test, y2_test)
viz.show();

# %% [markdown]
# ## 4. XGBoost

# %% [markdown]
# ### Vanilla XGBoost Model

# %%
from xgboost import XGBClassifier

# %%
xgb_model = XGBClassifier(random_state=101)

# %%
from sklearn.utils import class_weight

# %%
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y2_train)

# %%
xgb_model.fit(X2_train, y2_train, sample_weight=classes_weights)
# Out:
# [15:49:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=101, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=None, subsample=1, tree_method='exact',
# ...

# %%
eval_metric(xgb_model, X2_train, y2_train, X2_test, y2_test)
# Out:
# Test_Set
# [[288   5  41]
#  [ 15  67  79]
#  [ 26  27 895]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.86      0.87       334
#     Hispanic       0.68      0.42      0.52       161
#        White       0.88      0.94      0.91       948
#
#     accuracy                           0.87      1443
#    macro avg       0.81      0.74      0.77      1443
# weighted avg       0.86      0.87      0.86      1443
#
#
# Train_Set
# [[ 964    0    0]
#  [   0  518    0]
#  [   0    0 2844]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00       964
#     Hispanic       1.00      1.00      1.00       518
#        White       1.00      1.00      1.00      2844
#
#     accuracy                           1.00      4326
#    macro avg       1.00      1.00      1.00      4326
# weighted avg       1.00      1.00      1.00      4326

# %% [markdown]
# ### Cross Valdiate

# %%
xgb_model = XGBClassifier(random_state=101)

# %%
scores = cross_validate(xgb_model, X2_train, y2_train, scoring = scoring, cv = 10, fit_params={'sample_weight':classes_weights})
df_scores = pd.DataFrame(scores, index = range(1,11))
df_scores.mean()[2:]
# Out:
# [13:44:30] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:44:32] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:44:33] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %% [markdown]
# ### XGBoost Model GridsearchCV

# %%
xgb_model = XGBClassifier(random_state=101)

# %%
param_grid = {"n_estimators":[50, 100, 200, 300],
              'max_depth':[3,4,5,6], 
              "learning_rate": [0.1, 0.2],
             "subsample":[0.5, 0.8, 1], 
              "colsample_bytree":[0.5,0.7, 1]}

# %%
xgb_grid_model = GridSearchCV(xgb_model,
                             param_grid,
                             scoring=recall_Hispanic,
                             n_jobs=-1,
                             verbose=2)

# %%
xgb_grid_model.fit(X2_train, y2_train, sample_weight=classes_weights)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [15:19:17] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None,
#                                      enable_categorical=False, gamma=None,
#                                      gpu_id=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_delta_step=None,
# ...

# %%
xgb_grid_model.best_params_
# Out:
# {'colsample_bytree': 1,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'n_estimators': 100,
#  'subsample': 0.8}

# %%
xgb_grid_model.best_score_
# Out:
# 0.6274645257654967

# %%
eval_metric(xgb_grid_model, X2_train, y2_train, X2_test, y2_test)
# Out:
# Test_Set
# [[287  18  29]
#  [ 15 107  39]
#  [ 46 123 779]]
#               precision    recall  f1-score   support
#
#        Black       0.82      0.86      0.84       334
#     Hispanic       0.43      0.66      0.52       161
#        White       0.92      0.82      0.87       948
#
#     accuracy                           0.81      1443
#    macro avg       0.73      0.78      0.74      1443
# weighted avg       0.84      0.81      0.82      1443
#
#
# Train_Set
# [[ 918   21   25]
#  [  13  446   59]
#  [  74  268 2502]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.95      0.93       964
#     Hispanic       0.61      0.86      0.71       518
#        White       0.97      0.88      0.92      2844
#
#     accuracy                           0.89      4326
#    macro avg       0.83      0.90      0.86      4326
# weighted avg       0.91      0.89      0.90      4326

# %% [markdown]
# ### Precision Recall Curve

# %%
xgb_grid_model = XGBClassifier(colsample_bytree = 1,
                               learning_rate = 0.1,
                               max_depth = 3,
                               n_estimators = 100,
                               subsample = 0.8, 
                               random_state=101)

viz = PrecisionRecallCurve(
    xgb_grid_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1",
    sample_weight=classes_weights
)
viz.fit(X2_train, y2_train)
viz.score(X2_test, y2_test)
viz.show();
# Out:
# [20:00:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:00:18] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:00:19] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ### Feature Importance

# %%
xgb_grid_model = XGBClassifier(max_depth=10, max_features=15, min_samples_split=22, n_estimators=64, random_state=101)
xgb_grid_model.fit(X2_train, y2_train, sample_weight=classes_weights)
xgb_grid_model.feature_importances_
feats = pd.DataFrame(index=X2.columns, data=xgb_grid_model.feature_importances_, columns = ["Feature Importance"])
xgb_feature_imp = feats.sort_values("Feature Importance", ascending = False)
xgb_feature_imp
# Out:
# [19:59:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:576:
# Parameters: { "max_features", "min_samples_split" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:59:49] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                 Feature Importance
# elbowrestheight                              0.053
# buttockpopliteallength                       0.043
# sittingheight                                0.034
# ...

# %% [markdown]
# ## Comparing Models

# %% [markdown]
# Model skorlarini kiyasladigimizda, RF model ve XGBoost modellerde train datalarinin iyi sonuc vermesine karsin test datalarinin cok kotu skorlar verdigini goruyoruz. Bu modellerde overfitting problemi var. Parametreler ile oynasak bile skorlarin cok fazla iyilesemeyecegi aşikar. En iyi skoru Logistic Regression uzerinden kurdugumuz __pipe_model__' e ait oldugunu goruyoruz. Yolumuza bu model ile devam edecegiz.

# %%
eval_metric(pipe_model_vanilla, X_train, y_train, X_test, y_test)    # for Logisctic Regression
# Out:
# Test_Set
# [[296   3  35]
#  [  8  87  66]
#  [  8  19 921]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.89      0.92       334
#     Hispanic       0.80      0.54      0.64       161
#        White       0.90      0.97      0.94       948
#
#     accuracy                           0.90      1443
#    macro avg       0.88      0.80      0.83      1443
# weighted avg       0.90      0.90      0.90      1443
#
#
# Train_Set
# [[ 886   14   64]
#  [  27  284  207]
#  [  24   49 2771]]
#               precision    recall  f1-score   support
#
#        Black       0.95      0.92      0.93       964
#     Hispanic       0.82      0.55      0.66       518
#        White       0.91      0.97      0.94      2844
#
#     accuracy                           0.91      4326
#    macro avg       0.89      0.81      0.84      4326
# weighted avg       0.91      0.91      0.91      4326

# %%
eval_metric(pipe_model, X_train, y_train, X_test, y_test)    # for Logisctic Regression
# Out:
# Test_Set
# [[303  19  12]
#  [  8 135  18]
#  [ 19 123 806]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.91      0.91       334
#     Hispanic       0.49      0.84      0.62       161
#        White       0.96      0.85      0.90       948
#
#     accuracy                           0.86      1443
#    macro avg       0.79      0.87      0.81      1443
# weighted avg       0.90      0.86      0.87      1443
#
#
# Train_Set
# [[ 904   37   23]
#  [  17  436   65]
#  [  55  337 2452]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.94      0.93       964
#     Hispanic       0.54      0.84      0.66       518
#        White       0.97      0.86      0.91      2844
#
#     accuracy                           0.88      4326
#    macro avg       0.81      0.88      0.83      4326
# weighted avg       0.91      0.88      0.89      4326

# %%
eval_metric(log_model_grid, X_train, y_train, X_test, y_test)      # for Logisctic Regression
# Out:
# Test_Set
# [[302  18  14]
#  [  8 132  21]
#  [ 21 129 798]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.90      0.91       334
#     Hispanic       0.47      0.82      0.60       161
#        White       0.96      0.84      0.90       948
#
#     accuracy                           0.85      1443
#    macro avg       0.78      0.86      0.80      1443
# weighted avg       0.89      0.85      0.87      1443
#
#
# Train_Set
# [[ 899   40   25]
#  [  22  419   77]
#  [  65  344 2435]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.93      0.92       964
#     Hispanic       0.52      0.81      0.63       518
#        White       0.96      0.86      0.91      2844
#
#     accuracy                           0.87      4326
#    macro avg       0.80      0.87      0.82      4326
# weighted avg       0.90      0.87      0.88      4326

# %%
eval_metric(pipe_svc_model, X_train, y_train, X_test, y_test)           # for SVC
# Out:
# Test_Set
# [[293  20  21]
#  [ 10 127  24]
#  [ 16 142 790]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.88      0.90       334
#     Hispanic       0.44      0.79      0.56       161
#        White       0.95      0.83      0.89       948
#
#     accuracy                           0.84      1443
#    macro avg       0.77      0.83      0.78      1443
# weighted avg       0.88      0.84      0.85      1443
#
#
# Train_Set
# [[ 887   39   38]
#  [  17  429   72]
#  [  55  382 2407]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92       964
#     Hispanic       0.50      0.83      0.63       518
#        White       0.96      0.85      0.90      2844
#
#     accuracy                           0.86      4326
#    macro avg       0.80      0.86      0.82      4326
# weighted avg       0.90      0.86      0.87      4326

# %%
eval_metric(svc_model_grid, X_train, y_train, X_test, y_test)             # for SVC
# Out:
# Test_Set
# [[302  17  15]
#  [  8 129  24]
#  [ 18 138 792]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.90      0.91       334
#     Hispanic       0.45      0.80      0.58       161
#        White       0.95      0.84      0.89       948
#
#     accuracy                           0.85      1443
#    macro avg       0.78      0.85      0.79      1443
# weighted avg       0.89      0.85      0.86      1443
#
#
# Train_Set
# [[ 890   42   32]
#  [  18  422   78]
#  [  51  348 2445]]
#               precision    recall  f1-score   support
#
#        Black       0.93      0.92      0.93       964
#     Hispanic       0.52      0.81      0.63       518
#        White       0.96      0.86      0.91      2844
#
#     accuracy                           0.87      4326
#    macro avg       0.80      0.87      0.82      4326
# weighted avg       0.90      0.87      0.88      4326

# %%
eval_metric(rf_model, X2_train, y2_train, X2_test, y2_test)             # for Random Forest
# Out:
# Test_Set
# [[222   0 112]
#  [ 12   3 146]
#  [  9   6 933]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.66      0.77       334
#     Hispanic       0.33      0.02      0.04       161
#        White       0.78      0.98      0.87       948
#
#     accuracy                           0.80      1443
#    macro avg       0.68      0.56      0.56      1443
# weighted avg       0.76      0.80      0.76      1443
#
#
# Train_Set
# [[ 964    0    0]
#  [   0  518    0]
#  [   0    0 2844]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00       964
#     Hispanic       1.00      1.00      1.00       518
#        White       1.00      1.00      1.00      2844
#
#     accuracy                           1.00      4326
#    macro avg       1.00      1.00      1.00      4326
# weighted avg       1.00      1.00      1.00      4326

# %%
eval_metric(rf_grid_model, X2_train, y2_train, X2_test, y2_test)        # for Random Forest
# Out:
# Test_Set
# [[265  10  59]
#  [ 23  54  84]
#  [ 48  96 804]]
#               precision    recall  f1-score   support
#
#        Black       0.79      0.79      0.79       334
#     Hispanic       0.34      0.34      0.34       161
#        White       0.85      0.85      0.85       948
#
#     accuracy                           0.78      1443
#    macro avg       0.66      0.66      0.66      1443
# weighted avg       0.78      0.78      0.78      1443
#
#
# Train_Set
# [[ 924    8   32]
#  [  13  468   37]
#  [  45   91 2708]]
#               precision    recall  f1-score   support
#
#        Black       0.94      0.96      0.95       964
#     Hispanic       0.83      0.90      0.86       518
#        White       0.98      0.95      0.96      2844
#
#     accuracy                           0.95      4326
#    macro avg       0.91      0.94      0.93      4326
# weighted avg       0.95      0.95      0.95      4326

# %%
eval_metric(xgb_model, X2_train, y2_train, X2_test, y2_test)               # for XGBoost
# Out:
# Test_Set
# [[288   5  41]
#  [ 15  67  79]
#  [ 26  27 895]]
#               precision    recall  f1-score   support
#
#        Black       0.88      0.86      0.87       334
#     Hispanic       0.68      0.42      0.52       161
#        White       0.88      0.94      0.91       948
#
#     accuracy                           0.87      1443
#    macro avg       0.81      0.74      0.77      1443
# weighted avg       0.86      0.87      0.86      1443
#
#
# Train_Set
# [[ 964    0    0]
#  [   0  518    0]
#  [   0    0 2844]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00       964
#     Hispanic       1.00      1.00      1.00       518
#        White       1.00      1.00      1.00      2844
#
#     accuracy                           1.00      4326
#    macro avg       1.00      1.00      1.00      4326
# weighted avg       1.00      1.00      1.00      4326

# %%
eval_metric(xgb_grid_model, X2_train, y2_train, X2_test, y2_test)         # for XGBoost
# Out:
# Test_Set
# [[275   4  55]
#  [ 12  44 105]
#  [ 18  11 919]]
#               precision    recall  f1-score   support
#
#        Black       0.90      0.82      0.86       334
#     Hispanic       0.75      0.27      0.40       161
#        White       0.85      0.97      0.91       948
#
#     accuracy                           0.86      1443
#    macro avg       0.83      0.69      0.72      1443
# weighted avg       0.85      0.86      0.84      1443
#
#
# Train_Set
# [[ 964    0    0]
#  [   0  518    0]
#  [   0    0 2844]]
#               precision    recall  f1-score   support
#
#        Black       1.00      1.00      1.00       964
#     Hispanic       1.00      1.00      1.00       518
#        White       1.00      1.00      1.00      2844
#
#     accuracy                           1.00      4326
#    macro avg       1.00      1.00      1.00      4326
# weighted avg       1.00      1.00      1.00      4326

# %% [markdown]
# ### Comparing Visualization

# %% [markdown]
# Modellerin genel performanslarina baktigimizda Hispanic class' ina ait en buyuk skorun yine __pipe_model__' de oldugunu goruyoruz :

# %%
viz = PrecisionRecallCurve(
    pipe_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],   # Tabloda isimler gorunsun diye bunu yazdik.
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
viz = PrecisionRecallCurve(
    pipe_svc_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],   # Tabloda isimler gorunsun diye bunu yazdik.
    cmap="Set1"
)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.show();

# %%
rf_grid_model = RandomForestClassifier(class_weight='balanced', max_depth=10, max_features=15, min_samples_split=22, n_estimators=64, random_state=101)

viz = PrecisionRecallCurve(
    rf_grid_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X2_train, y2_train)
viz.score(X2_test, y2_test)
viz.show();

# %%
xgb_grid_model = XGBClassifier(colsample_bytree = 1,
                               learning_rate = 0.1,
                               max_depth = 3,
                               n_estimators = 100,
                               subsample = 0.8, 
                               random_state=101)

viz = PrecisionRecallCurve(
    xgb_grid_model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1",
    sample_weight=classes_weights
)
viz.fit(X2_train, y2_train)
viz.score(X2_test, y2_test)
viz.show();
# Out:
# [12:37:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:37:23] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [12:37:24] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# # Final Model

# %% [markdown]
# Final modelimizi en iyi skoru aldigimiz Logistic Regression modele gore kurduk :

# %%
operations_weighted = [('scaler', MinMaxScaler()), ('log', LogisticRegression(class_weight='balanced', max_iter=10000, random_state = 101))]

# %%
log_final_model = Pipeline(steps=operations_weighted)

# %%
log_final_model.fit(X,y)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     random_state=101))])

# %%
X.describe()
# Out:
#        abdominalextensiondepthsitting  acromialheight  acromionradialelength  \
# count                        5769.000        5769.000               5769.000
# mean                          247.254        1408.630                328.072
# std                            37.458          78.303                 20.445
# min                           155.000        1146.000                249.000
# 25%                           220.000        1353.000                314.000
# 50%                           243.000        1412.000                328.000
# 75%                           272.000        1464.000                342.000
# max                           451.000        1683.000                393.000
#
#        anklecircumference  axillaheight  balloffootcircumference  \
# count            5769.000      5769.000                 5769.000
# mean              225.202      1301.903                  244.408
# std                15.966        71.261                   16.804
# ...

# %%
mean_df = X.describe().loc['mean']
mean_df
# Out:
# abdominalextensiondepthsitting                  247.254
# acromialheight                                 1408.630
# acromionradialelength                           328.072
# anklecircumference                              225.202
# axillaheight                                   1301.903
# balloffootcircumference                         244.408
# balloffootlength                                195.119
# biacromialbreadth                               399.706
# bicepscircumferenceflexed                       341.663
# bicristalbreadth                                274.903
# bideltoidbreadth                                491.455
# bimalleolarbreadth                               72.335
# bitragionchinarc                                324.962
# bitragionsubmandibulararc                       306.678
# bizygomaticbreadth                              139.529
# buttockcircumference                           1022.059
# buttockdepth                                    242.234
# ...

# %% [markdown]
# 203. sample' in hem gercek class' ina baktik hem de modelimizin tahmin etmesini istedik; ikisi de ayni sonucu verdi. Modelimiz dogru tahmin yapti :

# %%
log_final_model.predict(X.loc[[203]])
# Out:
# array(['Hispanic'], dtype=object)

# %%
y[203]
# Out:
# 'Hispanic'

# %% [markdown]
# Datanin mean degerleri ile elde ettigimiz sample' i modelimize predict icin verdigimizde 'White' tahmininde bulundu. (Datada en cok White class' i bulunuyor.)

# %%
log_final_model.predict([mean_df])
# Out:
# array(['White'], dtype=object)

# %%
from sklearn.metrics import matthews_corrcoef

y_pred = log_final_model.predict(X_test)

matthews_corrcoef(y_test, y_pred)
# Out:
# 0.7872854837973757

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(y_test, y_pred)
# Out:
# 0.7771865103979628

# %% [markdown]
# ---
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# # SMOTE
# https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

# %% [markdown]
# ##  Smote implement

# %%
#!pip install imblearn

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline as imbpipeline

# %%
over = SMOTE(sampling_strategy={"Hispanic": 1200})
under = RandomUnderSampler(sampling_strategy={"White": 2500})

# %%
X_resampled_over, y_resampled_over = over.fit_resample(X_train, y_train)

# %%
X_resampled_under, y_resampled_under = under.fit_resample(X_train, y_train)

# %%
y_resampled_under.value_counts()
# Out:
# White       2500
# Black        964
# Hispanic     518
# Name: DODRace, dtype: int64

# %%
y_resampled_over.value_counts()
# Out:
# White       2844
# Hispanic    1200
# Black        964
# Name: DODRace, dtype: int64

# %%
y_train.value_counts()
# Out:
# White       2844
# Black        964
# Hispanic     518
# Name: DODRace, dtype: int64

# %% [markdown]
# ## LOGISTIC Over/Under Sampling

# %% [markdown]
# Smote isleminden sonra da en iyi skoru Logistic Regression modelde aldigimizi goruyoruz. Modelimizi bir kez daha teyit etmis olduk.

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ('log', LogisticRegression(class_weight='balanced', max_iter=10000, random_state = 101))]

# %%
smote_pipeline_log = imbpipeline(steps=operations)

# %%
smote_pipeline_log.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={'Hispanic': 1200})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2500})),
#                 ('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     random_state=101))])

# %%
eval_metric(smote_pipeline_log, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[302  19  13]
#  [  9 121  31]
#  [ 20  95 833]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.90      0.91       334
#     Hispanic       0.51      0.75      0.61       161
#        White       0.95      0.88      0.91       948
#
#     accuracy                           0.87      1443
#    macro avg       0.79      0.84      0.81      1443
# weighted avg       0.89      0.87      0.88      1443
#
#
# Train_Set
# [[ 910   24   30]
#  [  30  381  107]
#  [  60  254 2530]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.94      0.93       964
#     Hispanic       0.58      0.74      0.65       518
#        White       0.95      0.89      0.92      2844
#
#     accuracy                           0.88      4326
#    macro avg       0.81      0.86      0.83      4326
# weighted avg       0.90      0.88      0.89      4326

# %% [markdown]
# ### Cross Validate

# %%
model = smote_pipeline_log = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.611
# test_precision_Hispanic   0.541
# test_recall_Hispanic      0.705
# dtype: float64

# %% [markdown]
# ## SVC Over/Under Sampling

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ('svc', SVC(class_weight = 'balanced', C = 27.825594022071257, gamma = 'auto',  random_state=101))]

# %%
smote_pipeline_svc = imbpipeline(steps=operations)

# %%
smote_pipeline_svc.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={'Hispanic': 1200})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2500})),
#                 ('scaler', MinMaxScaler()),
#                 ('svc',
#                  SVC(C=27.825594022071257, class_weight='balanced',
#                      gamma='auto', random_state=101))])

# %%
eval_metric(smote_pipeline_svc, X_train, y_train, X_test, y_test)
# Out:
# Test_Set
# [[306  14  14]
#  [ 11 114  36]
#  [ 16  86 846]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92       334
#     Hispanic       0.53      0.71      0.61       161
#        White       0.94      0.89      0.92       948
#
#     accuracy                           0.88      1443
#    macro avg       0.80      0.84      0.81      1443
# weighted avg       0.89      0.88      0.88      1443
#
#
# Train_Set
# [[ 903   28   33]
#  [  31  383  104]
#  [  54  252 2538]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.94      0.93       964
#     Hispanic       0.58      0.74      0.65       518
#        White       0.95      0.89      0.92      2844
#
#     accuracy                           0.88      4326
#    macro avg       0.81      0.86      0.83      4326
# weighted avg       0.90      0.88      0.89      4326

# %% [markdown]
# ### Cross Validate

# %%
model = smote_pipeline_svc = imbpipeline(steps=operations)

scores = cross_validate(model, X_train, y_train, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.612
# test_precision_Hispanic   0.553
# test_recall_Hispanic      0.687
# dtype: float64

# %% [markdown]
# ## Xgboost Over/ Under Sampling

# %%
smote_pipeline_xgb = XGBClassifier(colsample_bytree = 1, 
                                        learning_rate = 0.1,
                                        max_depth = 3,
                                        n_estimators = 100,
                                        subsample = 0.8, 
                                        random_state=101,
                                        )

# %%
smote_pipeline_xgb.fit(X2_train, y2_train, sample_weight=classes_weights)
# Out:
# [17:30:02] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1643227205751/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=101, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=None, subsample=0.8, tree_method='exact',
# ...

# %%
eval_metric(smote_pipeline_xgb, X2_train, y2_train, X2_test, y2_test)
# Out:
# Test_Set
# [[287  18  29]
#  [ 15 107  39]
#  [ 46 123 779]]
#               precision    recall  f1-score   support
#
#        Black       0.82      0.86      0.84       334
#     Hispanic       0.43      0.66      0.52       161
#        White       0.92      0.82      0.87       948
#
#     accuracy                           0.81      1443
#    macro avg       0.73      0.78      0.74      1443
# weighted avg       0.84      0.81      0.82      1443
#
#
# Train_Set
# [[ 918   21   25]
#  [  13  446   59]
#  [  74  268 2502]]
#               precision    recall  f1-score   support
#
#        Black       0.91      0.95      0.93       964
#     Hispanic       0.61      0.86      0.71       518
#        White       0.97      0.88      0.92      2844
#
#     accuracy                           0.89      4326
#    macro avg       0.83      0.90      0.86      4326
# weighted avg       0.91      0.89      0.90      4326

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# - Evaluation metrics
# https://towardsdatascience.com/comprehensive-guide-on-multiclass-classification-metrics-af94cfb83fbd

# %% [markdown]
# #  SHAP
#
# https://towardsdatascience.com/shap-explain-any-machine-learning-model-in-python-24207127cad7

# %% [markdown]
# Logistic Regression modelde Hispanic class' ina ait skorlari iyilestirebilmek icin Shap ile feature selection yapacagiz :

# %%
# !pip install shap

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model_shap = LogisticRegression(class_weight='balanced',max_iter=10000, random_state=101, penalty="l1", solver='saga')
model_shap.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=10000, penalty='l1',
#                    random_state=101, solver='saga')

# %%
eval_metric(model_shap, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Test_Set
# [[306  18  10]
#  [  8 134  19]
#  [ 18 122 808]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.92      0.92       334
#     Hispanic       0.49      0.83      0.62       161
#        White       0.97      0.85      0.91       948
#
#     accuracy                           0.86      1443
#    macro avg       0.79      0.87      0.81      1443
# weighted avg       0.90      0.86      0.88      1443
#
#
# Train_Set
# [[ 905   36   23]
#  [  20  432   66]
#  [  62  328 2454]]
#               precision    recall  f1-score   support
#
#        Black       0.92      0.94      0.93       964
#     Hispanic       0.54      0.83      0.66       518
#        White       0.97      0.86      0.91      2844
#
#     accuracy                           0.88      4326
#    macro avg       0.81      0.88      0.83      4326
# weighted avg       0.90      0.88      0.88      4326

# %%
import shap
explainer = shap.Explainer(model_shap, X_train)
start_index = 203
end_index = 204
shap_values = explainer.shap_values(X_test[start_index:end_index])

# %%
shap_values
# Out:
# [array([[-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          -6.17565073e+01,  0.00000000e+00, -3.33596872e+01,
#           0.00000000e+00,  0.00000000e+00,  8.82578685e+01,
#          -8.25779529e+01,  0.00000000e+00, -4.52520772e-01,
#          -9.75431441e+00, -1.04036311e+00,  0.00000000e+00,
#           0.00000000e+00,  1.25603097e+01,  1.66763564e+01,
#           5.66699409e+01,  1.09796554e+00,  0.00000000e+00,
#           0.00000000e+00,  8.60688384e+00,  0.00000000e+00,
#          -9.50654456e+00,  0.00000000e+00,  5.40730510e+01,
#           0.00000000e+00, -0.00000000e+00, -1.83567041e+00,
#          -3.92108330e+00,  2.82916572e+00,  0.00000000e+00,
#          -3.66120784e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  9.96208068e+01, -2.22206228e+01,
#           2.89234212e+01,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  5.92438374e+01, -6.56127802e+00,
#          -8.92931558e-02,  0.00000000e+00,  1.89863053e+00,
# ...

# %%
print(shap_values[0].shape)
# Out:
# (1, 232)

# %%
# %% >> Visualize local predictions
shap.initjs()
# Force plot
prediction = model_shap.predict(X_test[start_index:end_index])[0]
print(f"The log_model predicted: {prediction}")
shap.force_plot(explainer.expected_value[1],
                shap_values[0],
                X_test[start_index:end_index], # for values
                feature_names= X.columns,)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# ### Shap Values for All Data

# %%
explainer = shap.Explainer(model_shap, X_train_scaled)

shap_values = explainer.shap_values(X_test_scaled)

# %%
shap.summary_plot(shap_values, X_train_scaled, max_display=300,feature_names = X.columns)

# %% [markdown]
# Shap ile Hispanic class' ini tespit etmede en etkili feature' lari asagida sectik. Bu feature' lar ile modelimizi yeniden kuracagiz :

# %%
hispanic = ['forearmcircumferenceflexed', 'footbreadthhorizontal', 'headlength', 'Age', 'bitragionsubmandibulararc', 'buttockkneelength', 'hipbreadth', 'earlength', 'WritingPreference', 'SubjectsBirthLocation', 'bimalleolarbreadth', 'handbreadth', 'earprotrusion', 'tragiontopofhead', 'elbowrestheight', 'waistdepth', 'bizygomaticbreadth', 'tenthribheight', 'neckcircumference', 'eyeheightsitting', 'tibialheight', 'poplitealheight', 'abdominalextensiondepthsitting', 'shoulderlength', 'biacromialbreadth']

# %%
X3 = df[hispanic]    
X3 = pd.get_dummies(data=X3, drop_first=True)
y = df.DODRace

# %%
X3.shape
# Out:
# (5769, 160)

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y, test_size=0.2, random_state=101, stratify =y)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101,
                                                                    penalty="l1", solver='saga'))]
pipe_shap_model = Pipeline(steps=operations)

# %%
pipe_shap_model.fit(X_train3, y_train3)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     penalty='l1', random_state=101,
#                                     solver='saga'))])

# %%
eval_metric(pipe_shap_model, X_train3, y_train3, X_test3, y_test3)
# Out:
# Test_Set
# [[219  13  28]
#  [ 11 101  24]
#  [ 78 136 544]]
#               precision    recall  f1-score   support
#
#        Black       0.71      0.84      0.77       260
#     Hispanic       0.40      0.74      0.52       136
#        White       0.91      0.72      0.80       758
#
#     accuracy                           0.75      1154
#    macro avg       0.68      0.77      0.70      1154
# weighted avg       0.81      0.75      0.76      1154
#
#
# Train_Set
# [[ 874   59  105]
#  [  35  427   81]
#  [ 329  464 2241]]
#               precision    recall  f1-score   support
#
#        Black       0.71      0.84      0.77      1038
#     Hispanic       0.45      0.79      0.57       543
#        White       0.92      0.74      0.82      3034
#
#     accuracy                           0.77      4615
#    macro avg       0.69      0.79      0.72      4615
# weighted avg       0.82      0.77      0.78      4615

# %% [markdown]
# ### Cross Validate for Shap

# %%
model = Pipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.545
# test_precision_Hispanic   0.431
# test_recall_Hispanic      0.744
# dtype: float64

# %%
from yellowbrick.classifier import PrecisionRecallCurve
model = Pipeline(steps=operations)

viz = PrecisionRecallCurve(
    model,
    per_class=True, classes= ["Black", "Hispanic", "White"],
    cmap="Set1"
)
viz.fit(X_train3, y_train3)
viz.score(X_test3, y_test3)
viz.show();

# %% [markdown]
# ## SMOTE for X3 Dataset

# %% [markdown]
# Yeni feature' lar ile olusturdugumuz modelimize Smote islemini bir kez daha uygulayalim :

# %%
operations = [('o', over), ('u', under), ("scaler", MinMaxScaler()), 
              ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]

# %%
smote_pipeline_2 = imbpipeline(steps=operations)

# %%
smote_pipeline_2.fit(X_train3, y_train3)
# Out:
# Pipeline(steps=[('o', SMOTE(sampling_strategy={'Hispanic': 1200})),
#                 ('u', RandomUnderSampler(sampling_strategy={'White': 2500})),
#                 ('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     random_state=101))])

# %%
eval_metric(smote_pipeline_2, X_train3, y_train3, X_test3, y_test3)
# Out:
# Test_Set
# [[210  18  32]
#  [  8  98  30]
#  [ 77  92 589]]
#               precision    recall  f1-score   support
#
#        Black       0.71      0.81      0.76       260
#     Hispanic       0.47      0.72      0.57       136
#        White       0.90      0.78      0.84       758
#
#     accuracy                           0.78      1154
#    macro avg       0.70      0.77      0.72      1154
# weighted avg       0.81      0.78      0.79      1154
#
#
# Train_Set
# [[ 883   51  104]
#  [  43  386  114]
#  [ 340  366 2328]]
#               precision    recall  f1-score   support
#
#        Black       0.70      0.85      0.77      1038
#     Hispanic       0.48      0.71      0.57       543
#        White       0.91      0.77      0.83      3034
#
#     accuracy                           0.78      4615
#    macro avg       0.70      0.78      0.72      4615
# weighted avg       0.81      0.78      0.79      4615

# %% [markdown]
# ### Cross Validate

# %%
model = imbpipeline(steps=operations)

scores = cross_validate(model, X_train3, y_train3, scoring = scoring, cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_f1_Hispanic          0.558
# test_precision_Hispanic   0.472
# test_recall_Hispanic      0.685
# dtype: float64

# %% [markdown]
# ### Find the best threshold for multiclassification

# %%
y2 = y.map({"Hispanic":1, "White":0, "Black":0})

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(X3, y2, test_size=0.2, random_state=101, stratify =y2)

# %%
operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(class_weight='balanced',max_iter=10000,random_state=101))]
pipe_shap_model2 = Pipeline(steps=operations)

# %%
pipe_shap_model2.fit(X_train4, y_train4)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()),
#                 ('log',
#                  LogisticRegression(class_weight='balanced', max_iter=10000,
#                                     random_state=101))])

# %%
eval_metric(pipe_shap_model2, X_train4, y_train4, X_test4, y_test4)
# Out:
# Test_Set
# [[847 171]
#  [ 27 109]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.90      1018
#            1       0.39      0.80      0.52       136
#
#     accuracy                           0.83      1154
#    macro avg       0.68      0.82      0.71      1154
# weighted avg       0.90      0.83      0.85      1154
#
#
# Train_Set
# [[3394  678]
#  [  88  455]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.90      4072
#            1       0.40      0.84      0.54       543
#
#     accuracy                           0.83      4615
#    macro avg       0.69      0.84      0.72      4615
# weighted avg       0.91      0.83      0.86      4615

# %%
from sklearn.metrics import plot_roc_curve, plot_precision_recall_curve, roc_auc_score, auc, roc_curve, average_precision_score, precision_recall_curve

operations = [("scaler", MinMaxScaler()), ("log", LogisticRegression(max_iter=10000,random_state=101))]
log_basic_model = Pipeline(steps=operations)

log_basic_model.fit(X_train4, y_train4)
plot_precision_recall_curve(log_basic_model, X_train4, y_train4);

# %%
y_pred_proba = log_basic_model.predict_proba(X_train4)
average_precision_score(y_train4, y_pred_proba[:,1])
# Out:
# 0.7047246581140634

# %%
precisions, recalls, thresholds = precision_recall_curve(y_train4, y_pred_proba[:,1])

# %%
optimal_idx = np.argmax((2 * precisions * recalls) / (precisions + recalls))
optimal_threshold = thresholds[optimal_idx]
optimal_threshold
# Out:
# 0.2922661027247777

# %%
y_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_test4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)

# %% [markdown]
# best_treshold degerini de Logistic modelimize uygulayarak Hispanic class' ina ait recall skorunu %88' e kadar cikardik :

# %%
print(confusion_matrix(y_test4,y_pred2))
print(classification_report(y_test4,y_pred2))
# Out:
# [[684 334]
#  [ 16 120]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.67      0.80      1018
#            1       0.26      0.88      0.41       136
#
#     accuracy                           0.70      1154
#    macro avg       0.62      0.78      0.60      1154
# weighted avg       0.89      0.70      0.75      1154

# %%
y_train_pred2 = pd.Series(pipe_shap_model2.predict_proba(X_train4)[:,1]).apply(lambda x : 1 if x >= optimal_threshold else 0)
print(confusion_matrix(y_train4, y_train_pred2))
print(classification_report(y_train4, y_train_pred2))
# Out:
# [[2708 1364]
#  [  35  508]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.67      0.79      4072
#            1       0.27      0.94      0.42       543
#
#     accuracy                           0.70      4615
#    macro avg       0.63      0.80      0.61      4615
# weighted avg       0.90      0.70      0.75      4615

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
